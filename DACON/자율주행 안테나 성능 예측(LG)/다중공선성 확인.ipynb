# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from patsy import dmatrices
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
path = '/content/drive/MyDrive/DACON/lg_am/'

# %%
train = pd.read_csv(path + 'train.csv')
test = pd.read_csv(path + 'test.csv')
submission = pd.read_csv(path + 'sample_submission.csv')

# %%
train.columns
# Out:
# Index(['ID', 'X_01', 'X_02', 'X_03', 'X_04', 'X_05', 'X_06', 'X_07', 'X_08',
#        'X_09', 'X_10', 'X_11', 'X_12', 'X_13', 'X_14', 'X_15', 'X_16', 'X_17',
#        'X_18', 'X_19', 'X_20', 'X_21', 'X_22', 'X_23', 'X_24', 'X_25', 'X_26',
#        'X_27', 'X_28', 'X_29', 'X_30', 'X_31', 'X_32', 'X_33', 'X_34', 'X_35',
#        'X_36', 'X_37', 'X_38', 'X_39', 'X_40', 'X_41', 'X_42', 'X_43', 'X_44',
#        'X_45', 'X_46', 'X_47', 'X_48', 'X_49', 'X_50', 'X_51', 'X_52', 'X_53',
#        'X_54', 'X_55', 'X_56', 'Y_01', 'Y_02', 'Y_03', 'Y_04', 'Y_05', 'Y_06',
#        'Y_07', 'Y_08', 'Y_09', 'Y_10', 'Y_11', 'Y_12', 'Y_13', 'Y_14'],
#       dtype='object')

# %%
# sns.pairplot(train[['X_01', 'X_02', 'X_03', 'X_04', 'X_05', 'X_06', 'X_07', 'X_08',
#        'X_09', 'X_10', 'X_11', 'X_12', 'X_13', 'X_14', 'X_15', 'X_16', 'X_17',
#        'X_18', 'X_19', 'X_20', 'X_21', 'X_22', 'X_23', 'X_24', 'X_25', 'X_26',
#        'X_27', 'X_28', 'X_29', 'X_30', 'X_31', 'X_32', 'X_33', 'X_34', 'X_35',
#        'X_36', 'X_37', 'X_38', 'X_39', 'X_40', 'X_41', 'X_42', 'X_43', 'X_44',
#        'X_45', 'X_46', 'X_47', 'X_48', 'X_49', 'X_50', 'X_51', 'X_52', 'X_53',
#        'X_54', 'X_55', 'X_56']]);

# %%
train['intercept'] = 1

# %% [markdown]
# # Y_01

# %%
lm = sm.OLS(train['Y_01'], train[['X_01', 'X_02', 'X_03', 'X_04', 'X_05', 'X_06', 'X_07', 'X_08',
       'X_09', 'X_10', 'X_11', 'X_12', 'X_13', 'X_14', 'X_15', 'X_16', 'X_17',
       'X_18', 'X_19', 'X_20', 'X_21', 'X_22', 'X_23', 'X_24', 'X_25', 'X_26',
       'X_27', 'X_28', 'X_29', 'X_30', 'X_31', 'X_32', 'X_33', 'X_34', 'X_35',
       'X_36', 'X_37', 'X_38', 'X_39', 'X_40', 'X_41', 'X_42', 'X_43', 'X_44',
       'X_45', 'X_46', 'X_47', 'X_48', 'X_49', 'X_50', 'X_51', 'X_52', 'X_53',
       'X_54', 'X_55', 'X_56']])
results = lm.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Y_01   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     27.91
# Date:                Tue, 23 Aug 2022   Prob (F-statistic):          2.63e-264
# Time:                        13:03:33   Log-Likelihood:                -14603.
# No. Observations:               39607   AIC:                         2.931e+04
# Df Residuals:                   39554   BIC:                         2.977e+04
# Df Model:                          52
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# X_01          -0.0010      0.001     -0.810      0.418      -0.003       0.001
# ...

# %%
y, X = dmatrices('Y_01 ~ X_01 +  X_02 +  X_03 +  X_04 +  X_05 + X_06 + X_07 + X_08 + X_09 + X_10 + X_11 + X_12 + X_13 + X_14 + X_15 + X_16 + X_17 + X_18 + X_19 + X_20 + X_21 + X_22 + X_23 + X_24 + X_25 + X_26 + X_27 + X_28 + X_29 + X_30 + X_31 + X_32 + X_33 + X_34 + X_35 + X_36 + X_37 + X_38 + X_39 + X_40 + X_41 + X_42 +  X_43 + X_44 + X_45 + X_46 + X_47 + X_48 + X_49 + X_50 + X_51 + X_52 + X_53 + X_54 + X_55 + X_56', train, return_type = 'dataframe')

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns 
vif
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
#     VIF Factor   features
# 0     0.000000  Intercept
# 1     3.338393       X_01
# 2     1.008929       X_02
# 3     2.185961       X_03
# 4     0.000000       X_04
# 5     1.766929       X_05
# 6     2.345513       X_06
# 7     1.024752       X_07
# 8     1.117746       X_08
# 9     1.177054       X_09
# 10    5.767093       X_10
# 11    5.765482       X_11
# 12    2.327350       X_12
# 13   23.233465       X_13
# 14   24.649917       X_14
# 15   11.183650       X_15
# 16    5.147009       X_16
# 17   22.969227       X_17
# 18   14.625564       X_18
# 19    4.640636       X_19
# 20    4.942666       X_20
# 21    4.944909       X_21
# 22    4.684077       X_22
# 23    0.000000       X_23
# 24    4.421715       X_24
# 25    3.882702       X_25
# 26    4.004493       X_26
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(train[['X_45']])
train['X_45'] = scaler.transform(train[['X_45']])

# %%
lm = sm.OLS(train['Y_01'], train[['X_01', 'X_02', 'X_03', 'X_04', 'X_05', 'X_06', 'X_07', 'X_08',
       'X_09', 'X_10', 'X_11', 'X_12', 'X_14', 'X_15', 'X_16', 'X_17',
       'X_19', 'X_20', 'X_21', 'X_22', 'X_23', 'X_24', 'X_25', 'X_26',
       'X_27', 'X_28', 'X_29', 'X_30', 'X_31', 'X_32', 'X_33', 'X_34', 'X_35',
       'X_36', 'X_37', 'X_38', 'X_39', 'X_40', 'X_41', 'X_42', 'X_43', 'X_44',
       'X_46', 'X_47', 'X_48', 'X_49', 'X_50', 'X_51', 'X_52', 'X_53',
       'X_54', 'X_55', 'X_56']])
results = lm.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Y_01   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     25.76
# Date:                Mon, 22 Aug 2022   Prob (F-statistic):          3.85e-228
# Time:                        07:18:46   Log-Likelihood:                -14695.
# No. Observations:               39607   AIC:                         2.949e+04
# Df Residuals:                   39557   BIC:                         2.992e+04
# Df Model:                          49
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# X_01           0.0021      0.001      1.753      0.080      -0.000       0.004
# ...

# %%
y, X = dmatrices('Y_01 ~ X_01 +  X_02 +  X_03 +  X_04 +  X_05 + X_06 + X_07 + X_08 + X_09 + X_10 + X_11 + X_12 + X_14 + X_15 + X_16 + X_17 + X_19 + X_20 + X_21 + X_22 + X_23 + X_24 + X_25 + X_26 + X_27 + X_28 + X_29 + X_30 + X_31 + X_32 + X_33 + X_34 + X_35 + X_36 + X_37 + X_38 + X_39 + X_40 + X_41 + X_42 +  X_43 + X_44 + X_46 + X_47 + X_48 + X_49 + X_50 + X_51 + X_52 + X_53 + X_54 + X_55 + X_56', train, return_type = 'dataframe')

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns 
vif
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
#     VIF Factor   features
# 0     0.000000  Intercept
# 1     3.212397       X_01
# 2     1.008776       X_02
# 3     2.181092       X_03
# 4     0.000000       X_04
# 5     1.765861       X_05
# 6     2.343771       X_06
# 7     1.024361       X_07
# 8     1.115348       X_08
# 9     1.168224       X_09
# 10    5.765745       X_10
# 11    5.764549       X_11
# 12    2.002926       X_12
# 13    6.752191       X_14
# 14    6.805958       X_15
# 15    4.401461       X_16
# 16    4.571300       X_17
# 17    4.636915       X_19
# 18    4.929181       X_20
# 19    4.941746       X_21
# 20    4.670828       X_22
# 21    0.000000       X_23
# 22    4.412449       X_24
# 23    3.874006       X_25
# 24    3.999273       X_26
# 25    3.310576       X_27
# 26    2.930615       X_28
# ...

# %% [markdown]
# #Y_02

# %%
lm = sm.OLS(train['Y_02'], train[['X_01', 'X_02', 'X_03', 'X_04', 'X_05', 'X_06', 'X_07', 'X_08',
       'X_09', 'X_10', 'X_11', 'X_12', 'X_13', 'X_14', 'X_15', 'X_16', 'X_17',
       'X_18', 'X_19', 'X_20', 'X_21', 'X_22', 'X_23', 'X_24', 'X_25', 'X_26',
       'X_27', 'X_28', 'X_29', 'X_30', 'X_31', 'X_32', 'X_33', 'X_34', 'X_35',
       'X_36', 'X_37', 'X_38', 'X_39', 'X_40', 'X_41', 'X_42', 'X_43', 'X_44',
       'X_45', 'X_46', 'X_47', 'X_48', 'X_49', 'X_50', 'X_51', 'X_52', 'X_53',
       'X_54', 'X_55', 'X_56']])
results = lm.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Y_02   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     29.04
# Date:                Mon, 22 Aug 2022   Prob (F-statistic):          3.64e-276
# Time:                        07:19:02   Log-Likelihood:                -17782.
# No. Observations:               39607   AIC:                         3.567e+04
# Df Residuals:                   39554   BIC:                         3.613e+04
# Df Model:                          52
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# X_01          -0.0026      0.001     -1.953      0.051      -0.005    8.82e-06
# ...

# %%
y, X = dmatrices('Y_02 ~ X_01 +  X_02 +  X_03 +  X_04 +  X_05 + X_06 + X_07 + X_08 + X_09 + X_10 + X_11 + X_12 + X_13 + X_14 + X_15 + X_16 + X_17 + X_18 + X_19 + X_20 + X_21 + X_22 + X_23 + X_24 + X_25 + X_26 + X_27 + X_28 + X_29 + X_30 + X_31 + X_32 + X_33 + X_34 + X_35 + X_36 + X_37 + X_38 + X_39 + X_40 + X_41 + X_42 +  X_43 + X_44 + X_45 + X_46 + X_47 + X_48 + X_49 + X_50 + X_51 + X_52 + X_53 + X_54 + X_55 + X_56', train, return_type = 'dataframe')

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns 
vif
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
#     VIF Factor   features
# 0     0.000000  Intercept
# 1     3.338393       X_01
# 2     1.008929       X_02
# 3     2.185961       X_03
# 4     0.000000       X_04
# 5     1.766929       X_05
# 6     2.345513       X_06
# 7     1.024752       X_07
# 8     1.117746       X_08
# 9     1.177054       X_09
# 10    5.767093       X_10
# 11    5.765482       X_11
# 12    2.327350       X_12
# 13   23.233465       X_13
# 14   24.649917       X_14
# 15   11.183650       X_15
# 16    5.147009       X_16
# 17   22.969227       X_17
# 18   14.625564       X_18
# 19    4.640636       X_19
# 20    4.942666       X_20
# 21    4.944909       X_21
# 22    4.684077       X_22
# 23    0.000000       X_23
# 24    4.421715       X_24
# 25    3.882702       X_25
# 26    4.004493       X_26
# ...

# %%
lm = sm.OLS(train['Y_02'], train[['X_01', 'X_02', 'X_03', 'X_04', 'X_05', 'X_06', 'X_07', 'X_08',
       'X_09', 'X_10', 'X_11', 'X_12', 'X_14', 'X_15', 'X_16', 'X_17',
       'X_18', 'X_19', 'X_20', 'X_21', 'X_22', 'X_23', 'X_24', 'X_25', 'X_26',
       'X_27', 'X_28', 'X_29', 'X_30', 'X_31', 'X_32', 'X_33', 'X_34', 'X_35',
       'X_36', 'X_37', 'X_38', 'X_39', 'X_40', 'X_41', 'X_42', 'X_43', 'X_44',
       'X_45', 'X_46', 'X_47', 'X_48', 'X_49', 'X_50', 'X_51', 'X_52', 'X_53',
       'X_54', 'X_55', 'X_56']])
results = lm.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Y_02   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.035
# Method:                 Least Squares   F-statistic:                     30.15
# Date:                Mon, 22 Aug 2022   Prob (F-statistic):          4.69e-277
# Time:                        07:26:31   Log-Likelihood:                -17783.
# No. Observations:               39607   AIC:                         3.567e+04
# Df Residuals:                   39556   BIC:                         3.611e+04
# Df Model:                          50
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# X_01          -0.0022      0.001     -1.696      0.090      -0.005       0.000
# ...

# %%
y, X = dmatrices('Y_02 ~ X_01 +  X_02 +  X_03 +  X_04 +  X_05 + X_06 + X_07 + X_08 + X_09 + X_10 + X_11 + X_12 + X_14 + X_15 + X_16 + X_17 + X_18 + X_19 + X_20 + X_21 + X_22 + X_23 + X_24 + X_25 + X_26 + X_27 + X_28 + X_29 + X_30 + X_31 + X_32 + X_33 + X_34 + X_35 + X_36 + X_37 + X_38 + X_39 + X_40 + X_41 + X_42 +  X_43 + X_44 + X_45 + X_46 + X_47 + X_48 + X_49 + X_50 + X_51 + X_52 + X_53 + X_54 + X_55 + X_56', train, return_type = 'dataframe')

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns 
vif
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
#     VIF Factor   features
# 0     0.000000  Intercept
# 1     3.242996       X_01
# 2     1.008876       X_02
# 3     2.155509       X_03
# 4     0.000000       X_04
# 5     1.765650       X_05
# 6     2.344727       X_06
# 7     1.024669       X_07
# 8     1.117161       X_08
# 9     1.175967       X_09
# 10    5.767086       X_10
# 11    5.765465       X_11
# 12    2.275112       X_12
# 13    6.720145       X_15
# 14    4.692649       X_16
# 15    3.843463       X_17
# 16   11.693819       X_18
# 17    4.578922       X_19
# 18    4.730390       X_20
# 19    4.932501       X_21
# 20    4.550508       X_22
# 21    0.000000       X_23
# 22    4.414074       X_24
# 23    3.876479       X_25
# 24    3.986646       X_26
# 25    3.310494       X_27
# 26    2.930973       X_28
# ...

# %% [markdown]
# #Y_03

# %%
lm = sm.OLS(train['Y_03'], train[['X_01', 'X_02', 'X_03', 'X_04', 'X_05', 'X_06', 'X_07', 'X_08',
       'X_09', 'X_10', 'X_11', 'X_12', 'X_13', 'X_14', 'X_15', 'X_16', 'X_17',
       'X_18', 'X_19', 'X_20', 'X_21', 'X_22', 'X_23', 'X_24', 'X_25', 'X_26',
       'X_27', 'X_28', 'X_29', 'X_30', 'X_31', 'X_32', 'X_33', 'X_34', 'X_35',
       'X_36', 'X_37', 'X_38', 'X_39', 'X_40', 'X_41', 'X_42', 'X_43', 'X_44',
       'X_45', 'X_46', 'X_47', 'X_48', 'X_49', 'X_50', 'X_51', 'X_52', 'X_53',
       'X_54', 'X_55', 'X_56']])
results = lm.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Y_03   R-squared:                       0.030
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     23.26
# Date:                Mon, 22 Aug 2022   Prob (F-statistic):          1.96e-215
# Time:                        07:19:32   Log-Likelihood:                -15302.
# No. Observations:               39607   AIC:                         3.071e+04
# Df Residuals:                   39554   BIC:                         3.117e+04
# Df Model:                          52
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# X_01          -0.0038      0.001     -3.047      0.002      -0.006      -0.001
# ...

# %%
y, X = dmatrices('Y_03 ~ X_01 +  X_02 +  X_03 +  X_04 +  X_05 + X_06 + X_07 + X_08 + X_09 + X_10 + X_11 + X_12 + X_13 + X_14 + X_15 + X_16 + X_17 + X_18 + X_19 + X_20 + X_21 + X_22 + X_23 + X_24 + X_25 + X_26 + X_27 + X_28 + X_29 + X_30 + X_31 + X_32 + X_33 + X_34 + X_35 + X_36 + X_37 + X_38 + X_39 + X_40 + X_41 + X_42 +  X_43 + X_44 + X_45 + X_46 + X_47 + X_48 + X_49 + X_50 + X_51 + X_52 + X_53 + X_54 + X_55 + X_56', train, return_type = 'dataframe')

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns 
vif
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py:1715: RuntimeWarning: divide by zero encountered in double_scalars
#   return 1 - self.ssr/self.centered_tss
#     VIF Factor   features
# 0     0.000000  Intercept
# 1     3.338393       X_01
# 2     1.008929       X_02
# 3     2.185961       X_03
# 4     0.000000       X_04
# 5     1.766929       X_05
# 6     2.345513       X_06
# 7     1.024752       X_07
# 8     1.117746       X_08
# 9     1.177054       X_09
# 10    5.767093       X_10
# 11    5.765482       X_11
# 12    2.327350       X_12
# 13   23.233465       X_13
# 14   24.649917       X_14
# 15   11.183650       X_15
# 16    5.147009       X_16
# 17   22.969227       X_17
# 18   14.625564       X_18
# 19    4.640636       X_19
# 20    4.942666       X_20
# 21    4.944909       X_21
# 22    4.684077       X_22
# 23    0.000000       X_23
# 24    4.421715       X_24
# 25    3.882702       X_25
# 26    4.004493       X_26
# ...
