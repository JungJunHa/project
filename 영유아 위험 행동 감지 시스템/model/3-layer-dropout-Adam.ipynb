# %%
import keras
from keras import applications
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.models import Sequential, Model 
from keras.layers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
# import keras_metrics as km
from keras import regularizers, optimizers
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import multilabel_confusion_matrix
from sklearn.metrics import accuracy_score
import math

# %%
data_dir = "/content/drive/MyDrive/video_data"
img_height , img_width = 64, 64
seq_len = 16

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
classes = ["fall", "fall_down", "grab", "swallow", "walk","sit"]

# %%
def frames_extraction(video_path):
    frames_list = []
     
    vidcap = cv2.VideoCapture(video_path)
    total_frames = vidcap.get(cv2.CAP_PROP_FRAME_COUNT)

    frames_step = total_frames//seq_len
 
    for j in range(seq_len):
        #here, we set the parameter 1 which is the frame number to the frame (i*frames_step)
        vidcap.set(1,j*frames_step)
        success,image = vidcap.read()  
        #save your image
        if success:
          image = cv2.resize(image, (img_height, img_width))
          frames_list.append(image)
        else:
          print("Defected frame {}".format(video_path))
          break

    return frames_list

# %%
def create_data(input_dir):
    X = []
    Y = []
     
    classes_list = os.listdir(input_dir)
     
    for c in classes_list:
        print(c)
        files_list = os.listdir(os.path.join(input_dir, c))
        for f in files_list:
            frames = frames_extraction(os.path.join(os.path.join(input_dir, c), f))
            if len(frames) == seq_len:
                X.append(frames)
             
                y = [0]*len(classes)
                y[classes.index(c)] = 1
                Y.append(y)
     
    X = np.asarray(X)
    Y = np.asarray(Y)
    return X, Y

# %%
X, Y = create_data(data_dir)
 
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, shuffle=True, random_state=0)
# Out:
# walk
# fall_down
# swallow
# Defected frame /content/drive/MyDrive/video_data/swallow/70.mov
# fall
# grab
# sit

# %%
model = Sequential()

model.add(ConvLSTM2D(filters = 128, kernel_size = (3, 3),strides = (2,2), return_sequences = True, data_format = "channels_last", input_shape = (seq_len, img_height, img_width, 3)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(ConvLSTM2D(filters = 64, kernel_size = (3, 3),strides = (2,2), return_sequences = True, data_format = "channels_last"))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(ConvLSTM2D(filters = 32, kernel_size = (3, 3),strides = (2,2), return_sequences = False, data_format = "channels_last"))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(256, activation="relu"))
model.add(Dropout(0.2))
model.add(Dense(6, activation = "softmax"))
 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d (ConvLSTM2D)    (None, 16, 31, 31, 128)   604160
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16, 31, 31, 128)   512
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 31, 31, 128)   0
# _________________________________________________________________
# conv_lst_m2d_1 (ConvLSTM2D)  (None, 16, 15, 15, 64)    442624
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 15, 15, 64)    256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 15, 15, 64)    0
# _________________________________________________________________
# conv_lst_m2d_2 (ConvLSTM2D)  (None, 7, 7, 32)          110720
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 7, 7, 32)          128
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 7, 7, 32)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1568)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               401664
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 1542
# =================================================================
# Total params: 1,561,606
# Trainable params: 1,561,158
# Non-trainable params: 448
# _________________________________________________________________

# %%
def schedular(epoch):
  if epoch < 10:
    return 0.001
  else:
    return 0.001 * math.exp(0.1*(10-epoch))

# %%
opt = optimizers.Adam(lr=0.001)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=["accuracy"])
 
earlystop = EarlyStopping(patience=7)
callbacks = tf.keras.callbacks.LearningRateScheduler(schedular)
 
history = model.fit(x = X_train, y = y_train, epochs=20, batch_size = 16, shuffle=True, validation_split=0.2, callbacks=[callbacks])

import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val','accuracy','val_accuracy'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/20
# 31/31 [==============================] - 640s 20s/step - loss: 2.6169 - accuracy: 0.2579 - val_loss: 1.8032 - val_accuracy: 0.3577
# Epoch 2/20
# 31/31 [==============================] - 608s 20s/step - loss: 2.2014 - accuracy: 0.3978 - val_loss: 1.7644 - val_accuracy: 0.3740
# Epoch 3/20
# 31/31 [==============================] - 610s 20s/step - loss: 1.8888 - accuracy: 0.4339 - val_loss: 1.7206 - val_accuracy: 0.3902
# Epoch 4/20
# 31/31 [==============================] - 613s 20s/step - loss: 1.7905 - accuracy: 0.4107 - val_loss: 1.6084 - val_accuracy: 0.3740
# Epoch 5/20
# 31/31 [==============================] - 611s 20s/step - loss: 1.4582 - accuracy: 0.5728 - val_loss: 2.9692 - val_accuracy: 0.1626
# Epoch 6/20
# 31/31 [==============================] - 614s 20s/step - loss: 1.3441 - accuracy: 0.5178 - val_loss: 2.4975 - val_accuracy: 0.3577
# Epoch 7/20
# 31/31 [==============================] - 613s 20s/step - loss: 1.3451 - accuracy: 0.5661 - val_loss: 5.8271 - val_accuracy: 0.1545
# Epoch 8/20
# 31/31 [==============================] - 614s 20s/step - loss: 1.3036 - accuracy: 0.5825 - val_loss: 2.3290 - val_accuracy: 0.3089
# Epoch 9/20
# 31/31 [==============================] - 613s 20s/step - loss: 1.1532 - accuracy: 0.5956 - val_loss: 2.9904 - val_accuracy: 0.3089
# Epoch 10/20
# 31/31 [==============================] - 617s 20s/step - loss: 1.0651 - accuracy: 0.6346 - val_loss: 3.4714 - val_accuracy: 0.2114
# Epoch 11/20
# 31/31 [==============================] - 619s 20s/step - loss: 1.1559 - accuracy: 0.5932 - val_loss: 2.5562 - val_accuracy: 0.2764
# Epoch 12/20
# 31/31 [==============================] - 621s 20s/step - loss: 0.8094 - accuracy: 0.7075 - val_loss: 5.8336 - val_accuracy: 0.1870
# Epoch 13/20
# 31/31 [==============================] - 619s 20s/step - loss: 0.9122 - accuracy: 0.6715 - val_loss: 3.5946 - val_accuracy: 0.1789
# Epoch 14/20
# 31/31 [==============================] - 639s 21s/step - loss: 0.7607 - accuracy: 0.7354 - val_loss: 4.1482 - val_accuracy: 0.1870
# Epoch 15/20
# 31/31 [==============================] - 638s 21s/step - loss: 0.7641 - accuracy: 0.7069 - val_loss: 3.1853 - val_accuracy: 0.3008
# Epoch 16/20
# 31/31 [==============================] - 630s 20s/step - loss: 0.7118 - accuracy: 0.7452 - val_loss: 1.4880 - val_accuracy: 0.5285
# Epoch 17/20
# 31/31 [==============================] - 620s 20s/step - loss: 0.5269 - accuracy: 0.7955 - val_loss: 1.5741 - val_accuracy: 0.5041
# Epoch 18/20
# 31/31 [==============================] - 563s 18s/step - loss: 0.5091 - accuracy: 0.7878 - val_loss: 1.3245 - val_accuracy: 0.5203
# Epoch 19/20
# 31/31 [==============================] - 565s 18s/step - loss: 0.4861 - accuracy: 0.8018 - val_loss: 1.2843 - val_accuracy: 0.5285
# Epoch 20/20
# 31/31 [==============================] - 564s 18s/step - loss: 0.3854 - accuracy: 0.8667 - val_loss: 1.3993 - val_accuracy: 0.5610

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
y_pred = model.predict(X_test) 
y_pred = np.argmax(y_pred, axis = 1)
y_test = np.argmax(y_test, axis = 1)
 
print(classification_report(y_test, y_pred))

print('accuracy score : {}'.format(accuracy_score(y_pred, y_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.30      0.37        10
#            1       0.53      0.79      0.64        53
#            2       0.86      0.63      0.73        19
#            3       0.82      0.90      0.86        10
#            4       0.71      0.47      0.56        43
#            5       0.75      0.63      0.69        19
#
#     accuracy                           0.64       154
#    macro avg       0.70      0.62      0.64       154
# weighted avg       0.67      0.64      0.63       154
#
# accuracy score : 0.6363636363636364
